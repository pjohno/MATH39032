# %%
from MathFinanceWorkshop import MFW_Simulation
import numpy as np
Model = MFW_Simulation()

# %%
Model.runCompetitionData(".competitionData.txt")
# Out:
#  Strategy generates average return  -1.091893061608023 % and a volatility of  6.563112057508355 %
